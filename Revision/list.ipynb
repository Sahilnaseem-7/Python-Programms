# %%
#printing lists of numbers
import random
#prinint 10 random numbers in the list
list = [random.randint(0,100) for i in range (10)]
print(f"The randomly generated list is : {list} ")
#updating the list with index
index = int(input("Enter the index in which value is to changed in range from 1 to 10"))
index-=1
list[index] = random.randint(0,1000)
print(f"The updated list is : {list}")
# Out:
# The randomly generated list is : [90, 57, 30, 14, 47, 91, 59, 22, 39, 24]
# The updated list is : [90, 57, 30, 14, 47, 91, 59, 22, 783, 24]

# %%
#Playing with lists 
import random 
#print the list again with numbers ranging to upto 10000
list = [random.randint(0,10000) for i in range (10)]
print(f"The given lsit is : {list}")

#Multiplying the list 
num = int(input("Enter the desired number by which to be multiplied in range from 1 to 10"))
list_updated = [x * num for x in list]
print(f"The updated list is : {list_updated}")
#Dividing the list
num = int(input("Enter the desired number by which to be divided in range from 1 to 10"))
list_updated = [x / num for x in list]
print(f"The updated list is : {list_updated}")
# Out:
# The given lsit is : [9284, 2138, 5280, 911, 1440, 8657, 1777, 5220, 115, 626]
# The updated list is : [46420, 10690, 26400, 4555, 7200, 43285, 8885, 26100, 575, 3130]
# The updated list is : [4642.0, 1069.0, 2640.0, 455.5, 720.0, 4328.5, 888.5, 2610.0, 57.5, 313.0]

# %%
# Out:
# The given list is : [469, 306, 153, 610, 940, 321, 190, 712, 615, 265]
